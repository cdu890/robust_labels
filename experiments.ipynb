# %% [markdown]
# This file runs additional experiments: (1) entropy experiment, (2) category overlap experiment.

# %%
import os
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
root = '/gdrive/MyDrive/cifar10_resnet/original/label_representations/' 
os.chdir(root)

# %%
import time

# %%
! pip install torchtoolbox
# Out:
# ...
#      |████████████████████████████████| 84 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 64.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 64.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 51.4 MB/s
# ...
#      |████████████████████████████████| 77 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 63.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# # Entropy Experiment

# %% [markdown]
# ## Step 1. Baseline accuracies

# %% [markdown]
# ### Dimension = 1

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=1
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=1 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=1/normal_dim=1_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=1/normal_dim=1_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=1_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=1/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 5

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=5
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=5 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=5/normal_dim=5_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=5/normal_dim=5_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=5_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=5/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 10

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=10
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=10 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=10/normal_dim=10_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=10/normal_dim=10_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=10_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=10/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 30

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=30
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=30 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=30/normal_dim=30_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=30/normal_dim=30_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=30_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=30/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 50

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=50
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=50 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=50/normal_dim=50_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=50/normal_dim=50_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=50_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=50/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 100

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=100
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=100 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=100/normal_dim=100_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=100/normal_dim=100_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=100_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=100/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 200

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=200
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=200 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=200/normal_dim=200_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=200/normal_dim=200_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=200_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=200/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 500

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=500
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=500 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=500/normal_dim=500_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=500/normal_dim=500_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=500_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=500/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 1000

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=1000
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=1000 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=1000/normal_dim=1000_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=1000/normal_dim=1000_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=1000_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=1000/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 2000

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=2000
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=2000 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=2000/normal_dim=2000_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=2000/normal_dim=2000_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=2000_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=2000/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Dimension = 4000

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=4000
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 normal_dim=4000 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=4000/normal_dim=4000_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_normal_dim=4000/normal_dim=4000_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_normal_dim=4000_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_normal_dim=4000/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ## Step 2. Attacking

# %% [markdown]
# ### Dimension = 5

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=5
# Out:
# Start attacking cifar10 normal_dim=5 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=5/normal_dim=5_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_normal_dim=5/normal_dim=5_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 7549 / 10000 = 0.7549
# Epsilon: 0.05	Test Accuracy = 4308 / 10000 = 0.4308
# ...

# %% [markdown]
# ### Dimension = 50

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=50
# Out:
# Start attacking cifar10 normal_dim=50 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=50/normal_dim=50_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_normal_dim=50/normal_dim=50_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 7513 / 10000 = 0.7513
# Epsilon: 0.05	Test Accuracy = 4335 / 10000 = 0.4335
# ...

# %% [markdown]
# ### Dimension = 200

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=200
# Out:
# Start attacking cifar10 normal_dim=200 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=200/normal_dim=200_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_normal_dim=200/normal_dim=200_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 7476 / 10000 = 0.7476
# Epsilon: 0.05	Test Accuracy = 4046 / 10000 = 0.4046
# ...

# %% [markdown]
# ### Dimension = 1000

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=1000
# Out:
# Start attacking cifar10 normal_dim=1000 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=1000/normal_dim=1000_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_normal_dim=1000/normal_dim=1000_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 7612 / 10000 = 0.7612
# Epsilon: 0.05	Test Accuracy = 3435 / 10000 = 0.3435
# ...

# %% [markdown]
# ### Dimension = 4000

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label normal_dim=4000
# Out:
# Start attacking cifar10 normal_dim=4000 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_normal_dim=4000/normal_dim=4000_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_normal_dim=4000/normal_dim=4000_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 7631 / 10000 = 0.7631
# Epsilon: 0.05	Test Accuracy = 2765 / 10000 = 0.2765
# ...

# %% [markdown]
# # Overlap Experiment

# %% [markdown]
# Keeping dimension=50, entropy = 5.64

# %% [markdown]
# ## Step 1. Baseline accuracies

# %% [markdown]
# ### Gap = 10

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=10 --label_dir ./labels/label_files/overlap
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 uniform_gap=10 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=10/uniform_gap=10_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_uniform_gap=10/uniform_gap=10_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_uniform_gap=10_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_uniform_gap=10/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Gap = 1

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=1 --label_dir ./labels/label_files/overlap
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 uniform_gap=1 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=1/uniform_gap=1_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_uniform_gap=1/uniform_gap=1_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_uniform_gap=1_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_uniform_gap=1/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Gap = 0.1

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=0.1 --label_dir ./labels/label_files/overlap
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 uniform_gap=0.1 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0.1/uniform_gap=0.1_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0.1/uniform_gap=0.1_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_uniform_gap=0.1_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0.1/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ### Gap = 0

# %%
start = time.time()
! python train_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=0 --label_dir ./labels/label_files/overlap
end = time.time()
print("Time:", end-start)
# Out:
# Start training 100% cifar10 uniform_gap=0 model with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0/uniform_gap=0_seed7_resnet32_best_model.pth.
# Checkpoint location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0/uniform_gap=0_seed7_resnet32_checkpoint.pth.
# Log location: outputs/log/cifar10_uniform_gap=0_log.csv.
# Snapshots location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0/snapshots
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# ## Step 2. Attacking

# %% [markdown]
# ### Gap = 10

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=10 --label_dir ./labels/label_files/overlap
# Out:
# Start attacking cifar10 uniform_gap=10 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=10/uniform_gap=10_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_uniform_gap=10/uniform_gap=10_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 7915 / 10000 = 0.7915
# Epsilon: 0.05	Test Accuracy = 5621 / 10000 = 0.5621
# ...

# %% [markdown]
# ### Gap = 1

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=1 --label_dir ./labels/label_files/overlap
# Out:
# Start attacking cifar10 uniform_gap=1 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=1/uniform_gap=1_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_uniform_gap=1/uniform_gap=1_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 8587 / 10000 = 0.8587
# Epsilon: 0.05	Test Accuracy = 5524 / 10000 = 0.5524
# ...

# %% [markdown]
# ### Gap = 0.1

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=0.1 --label_dir ./labels/label_files/overlap
# Out:
# Start attacking cifar10 uniform_gap=0.1 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0.1/uniform_gap=0.1_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0.1/uniform_gap=0.1_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 8691 / 10000 = 0.8691
# Epsilon: 0.05	Test Accuracy = 5858 / 10000 = 0.5858
# ...

# %% [markdown]
# ### Gap = 0

# %%
! python3 attack_v2.py --model resnet32 --dataset cifar10 --seed 7 --label uniform_gap=0 --label_dir ./labels/label_files/overlap
# Out:
# Start attacking cifar10 uniform_gap=0 model (kNN) with manual seed 7 and model resnet32.
# Best model location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0/uniform_gap=0_seed7_resnet32_best_model.pth.
# Attack results location: outputs/cifar10/seed7/resnet32/model_uniform_gap=0/uniform_gap=0_seed7_resnet32_attack_results_NN.pth.
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test FGSM untargeted
# Epsilon: 0	Test Accuracy = 8740 / 10000 = 0.874
# Epsilon: 0.05	Test Accuracy = 5429 / 10000 = 0.5429
# ...
